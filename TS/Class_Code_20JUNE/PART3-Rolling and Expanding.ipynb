# %%
import pandas as pd

# %%
df = pd.read_csv(r'G:\Traning\Data/starbucks.csv',index_col='Date', parse_dates=True)

# %%
df.head()
# Out:
#               Close    Volume
# Date
# 2015-01-02  38.0061   6906098
# 2015-01-05  37.2781  11623796
# 2015-01-06  36.9748   7664340
# 2015-01-07  37.8848   9732554
# 2015-01-08  38.4961  13170548

# %%
df['Close'].plot(figsize=(12,5)).autoscale(axis='x',tight=True);

# %%
df.rolling(window=7).mean().head(15)
# Out:
#                 Close        Volume
# Date
# 2015-01-02        NaN           NaN
# 2015-01-05        NaN           NaN
# 2015-01-06        NaN           NaN
# 2015-01-07        NaN           NaN
# 2015-01-08        NaN           NaN
# 2015-01-09        NaN           NaN
# 2015-01-12  37.616786  1.238222e+07
# 2015-01-13  37.578786  1.297288e+07
# 2015-01-14  37.614786  1.264020e+07
# 2015-01-15  37.638114  1.270624e+07
# 2015-01-16  37.600114  1.260380e+07
# 2015-01-20  37.515786  1.225634e+07
# 2015-01-21  37.615786  9.868837e+06
# 2015-01-22  37.783114  1.185335e+07
# 2015-01-23  38.273129  1.571999e+07

# %%
df['Close'].plot(figsize=(12,5)).autoscale(axis='x',tight=True)
df.rolling(window=30).mean()['Close'].plot();

# %%
df['Close: 30 day means'] = df['Close'].rolling(window=30).mean()
df[['Close','Close: 30 day means']].plot(figsize=(12,5)).autoscale(axis='x',tight=True);

# %%
df['Close'].expanding(min_periods=30).mean().plot(figsize=(12,5))
